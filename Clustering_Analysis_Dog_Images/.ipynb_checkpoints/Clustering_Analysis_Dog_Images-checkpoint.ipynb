# %%
import xml.etree.ElementTree as ET
import cv2 as cv
import PIL
import os
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as implt
from PIL import Image
import cv2,glob, datetime
import torch
from torchvision import models, transforms
from torch.autograd import Variable
from torch.utils.data import DataLoader
import timm
import torch.nn as nn
from sklearn.decomposition import PCA

dog_images = glob.glob('./cropped100_dogs/*/*')
new_path='./cropped224_dogs'
os.makedirs(new_path, exist_ok=True)
count=0
imgs_n = []
true_labels=[]
for file in dog_images:
    new_path='./cropped224_dogs'
    img = Image.open(file)
    img2 = img.resize((224, 224), PIL.Image.LANCZOS)
    base_name = os.path.basename(file)
    new_path = os.path.join(new_path, base_name)
    img2.save(new_path)
    image_dog=cv.imread(new_path,1)
    imgn = cv.normalize(image_dog, None, 0, 255, cv.NORM_MINMAX)
    imgn = np.transpose(imgn, (2, 0, 1))
    imgs_n.append(imgn)
    if "n02099712" in file:
        true_labels.append('labrador')
    if "n02110185" in file:
        true_labels.append('husky')
    if "n02113186" in file:
        true_labels.append('cardigan')
    if "n02113799" in file:
        true_labels.append('poodle')
    count+=1
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
data_loader = DataLoader(imgs_n,batch_size = 32,shuffle = False,num_workers = 2)
model= timm.create_model(model_name = 'resnet18', pretrained = True)
model.fc = nn.Linear(512, 4)
model.to(device)


def get_features(name):
    def hook(model, input, output):
        features[name] = output.detach()
    return hook
model.global_pool.register_forward_hook(get_features('feats'))
PREDS = []
FEATS = []
features = {}
for idx, inputs in enumerate(data_loader):
    inputs = inputs.to(device).float()
    preds = model(inputs)
    PREDS.append(preds.detach().cpu().numpy())
    FEATS.append(features['feats'].cpu().numpy())
PREDS = np.concatenate(PREDS)
FEATS = np.concatenate(FEATS)
print('- preds shape:', PREDS.shape)
print('- feats shape:', FEATS.shape)

# Fit PCA
pca = PCA().fit(FEATS)

# Plot explained variance
plt.figure(figsize=(8, 6))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance vs. Number of Components')
plt.grid(True)
plt.show()
# Out:
# - preds shape: (747, 4)
# - feats shape: (747, 512)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
a = FEATS.reshape(FEATS.shape[0], -1)
b = PCA(n_components=100)
reduced_feats = b.fit_transform(a)
reduced_feats
# Out:
# array([[ 0.23767585, -1.0277604 ,  0.13022757, ..., -0.06420994,
#         -0.04939312,  0.31309867],
#        [-1.9899716 ,  0.07283028,  0.805163  , ...,  0.02471188,
#         -0.0072289 , -0.01096392],
#        [-0.37892744,  1.3745856 , -0.7945887 , ...,  0.31081152,
#         -0.27804217, -0.01149513],
#        ...,
#        [-0.8368153 , -1.235224  ,  0.66927385, ...,  0.03240895,
#         -0.05013726, -0.10751335],
#        [-1.5810279 ,  0.3978161 , -0.2555585 , ...,  0.02454861,
#         -0.00597044,  0.10054456],
#        [ 0.38945654,  1.8768713 , -0.09853762, ...,  0.10349637,
#         -0.0765778 ,  0.36145243]], dtype=float32)

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
kmeans1 = KMeans(init="random", n_clusters=4, n_init=4, random_state=0)
kmeans1.fit(reduced_feats)
fig, ax = plt.subplots(figsize=(4,4))
ax.scatter(reduced_feats[:, 0], reduced_feats[:, 1], s=10, c=kmeans1.labels_)
ax.scatter(kmeans1.cluster_centers_[:, 0], kmeans1.cluster_centers_[:, 1], s=20, c="r")
ax.set_title("KMeans-Random")
# Out:
# C:\Users\alejo\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# Text(0.5, 1.0, 'KMeans-Random')

# %%
kmeans2 = KMeans(init="k-means++", n_clusters=4, n_init=4, random_state=0)
kmeans2.fit(reduced_feats)
fig, ax = plt.subplots(figsize=(4,4))
ax.scatter(reduced_feats[:, 0], reduced_feats[:, 1], s=10, c=kmeans2.labels_)
ax.scatter(kmeans2.cluster_centers_[:, 0], kmeans2.cluster_centers_[:, 1], s=20, c="r")
ax.set_title("KMeans++")
# Out:
# C:\Users\alejo\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# Text(0.5, 1.0, 'KMeans++')

# %%
from sklearn.cluster import BisectingKMeans
bisect_means = BisectingKMeans(init="random", n_clusters=4, random_state=0)
bisect_means.fit(reduced_feats)
fig, ax = plt.subplots(figsize=(4, 4))
ax.scatter(reduced_feats[:, 0], reduced_feats[:, 1], s=10, c=bisect_means.labels_)
ax.scatter(bisect_means.cluster_centers_[:, 0], bisect_means.cluster_centers_[:, 1], s=20, c="r")
ax.set_title("BisectingKMeans")
# Out:
# C:\Users\alejo\anaconda3\Lib\site-packages\sklearn\cluster\_bisect_k_means.py:247: UserWarning: BisectingKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# Text(0.5, 1.0, 'BisectingKMeans')

# %%
from sklearn.cluster import SpectralClustering
### DEFAULT PARAMETERS ACCORDING TO THE ASSIGNMENT. Except n_cluster
spectral = SpectralClustering(n_clusters=4,eigen_solver=None, n_components=None, random_state=None, n_init=10, gamma=1.0, affinity='rbf', n_neighbors=10, eigen_tol='auto', assign_labels='kmeans', degree=3, coef0=1, kernel_params=None, n_jobs=None, verbose=False)
spectral.fit(reduced_feats)
fig, ax = plt.subplots(figsize=(4,4))
ax.scatter(reduced_feats[:, 0], reduced_feats[:, 1], s=10, c=spectral.labels_)
ax.set_title("spectral")
# Out:
# C:\Users\alejo\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# Text(0.5, 1.0, 'spectral')

# %%
from sklearn.cluster import AgglomerativeClustering

# Initialize Agglomerative Clustering without the deprecated 'affinity' parameter
aglomerative = AgglomerativeClustering(n_clusters=4, metric='euclidean', memory=None, connectivity=None, compute_full_tree='auto', linkage='ward', distance_threshold=None, compute_distances=False)
aglomerative.fit(reduced_feats)

# Plot the results
fig, ax = plt.subplots(figsize=(4,4))
ax.scatter(reduced_feats[:, 0], reduced_feats[:, 1], s=10, c=aglomerative.labels_)
ax.set_title("Wards method")
plt.show()

# %%
from sklearn.metrics import fowlkes_mallows_score
from sklearn.metrics import silhouette_samples, silhouette_score
methods=[kmeans1,kmeans2,bisect_means,spectral,aglomerative]
method_names = ["KMeans (Random)", "KMeans++", "Bisecting KMeans", "Spectral Clustering", 
                "Agglomerative Clustering"]
number=0
for method, name in zip(methods, method_names):
    fmi = fowlkes_mallows_score(true_labels, method.labels_)
    silhouette = silhouette_score(reduced_feats, method.labels_)
    print(f"Method: {name}")
    print(f"fmi Score: {fmi}")
    print(f"Silhouette Score: {silhouette}")

    count=+1
    #print('K-mean clustering and its variants for 𝐾 = 4:')
#fmi_kmeans1 = fowlkes_mallows_score(true_labels, kmeans1.labels_)
#print('Fowlkes-Mallows index for k-means clustering (init=Random):', fmi_kmeans1)
# Out:
# Method: KMeans (Random)
# fmi Score: 0.26167020678025976
# Silhouette Score: 0.04383433982729912
# Method: KMeans++
# fmi Score: 0.25783509498600643
# Silhouette Score: 0.04100751131772995
# Method: Bisecting KMeans
# fmi Score: 0.253058096141566
# Silhouette Score: 0.029184900224208832
# Method: Spectral Clustering
# fmi Score: 0.29536047730204357
# Silhouette Score: 0.008591401390731335
# Method: Agglomerative Clustering
# fmi Score: 0.26931939513243247
# Silhouette Score: 0.02870888262987137

# %%
#### NO LO HE AGREGADO PARA CALCULAR SUS INDICADORES PORQUE HAY QUE MODIFICAR SUS PARAMETROS QUE NO SIRVEN

from sklearn.cluster import DBSCAN
DBSCAN1=DBSCAN(eps=0.005, min_samples=1, metric='euclidean', metric_params=None, algorithm='auto', leaf_size=30, p=None, n_jobs=None)
DBSCAN1.fit(reduced_feats) 
fig, ax = plt.subplots(figsize=(4,4))
print('We have to use eps= 0.235 and min_sample=13 if we want to get 4 clusters')
ax.scatter(reduced_feats[:, 0], reduced_feats[:, 1], s=10, c=DBSCAN1.labels_)
ax.set_title("DBSCAN1")
# Out:
# We have to use eps= 0.235 and min_sample=13 if we want to get 4 clusters
# Text(0.5, 1.0, 'DBSCAN1')
